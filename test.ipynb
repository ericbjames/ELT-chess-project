# %%
import requests

headers={
    "Accept":"application/x-ndjson"
}
response = requests.get("https://lichess.org/api/player/top/200/bullet",headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# ...

# %%
import requests

headers={
    "Accept":"application/x-ndjson"
}
response = requests.get("https://lichess.org/api/games/user/Zolerix?rated=true&perfType=bullet&opening=true&max=100&pgnInJson=true",headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# ...
